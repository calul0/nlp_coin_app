# %% [markdown]
# # Analize Error

# %% [markdown]
# #### required process

# %%
from cnt.io import Database_Connection
import pandas as pd

dc =  Database_Connection("mysql+mysqlconnector://[user]:[password]@localhost:3306/nlp_challenge")

# %% [markdown]
# ### 1- analize performance group by categorys

# %%
categorys = dc.create_own_query("""select distinct comment from nlp_training_designs;""")
categorys
# Out:
# Engine(mysql+mysqlconnector://saif:***@localhost:3306/nlp_challenge)
#           comment
# 0         from CN
# 1       from OCRE
# 2    from RE_yaml
# 3  auto_generated

# %%
dict_categorys = dict()
dict_categorys["all"] = "all"
for cat in categorys['comment']:
    dict_categorys[cat] = cat

# %%
from flows.relational_extraction import WorkflowRelationalExtraction

# %%
re_flow = WorkflowRelationalExtraction()
result_dict = dict()
for cat in dict_categorys:
    result_dict[cat] = re_flow.run_process_with_path_and_data_and_entites(query_option=cat)
# Out:
# 2024-06-29 16:16:33,146 - database.connector:28 - INFO Database connection established successfully.
# /Users/saif.samir/PycharmProjects/nlp-private-learning/src/main/python/com/nlp-multilingual/database/operations.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(sql=query, con=self.mysql_connector)
# /Users/saif.samir/PycharmProjects/nlp-private-learning/src/main/python/com/nlp-multilingual/database/operations.py:48: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   table = pd.read_sql_query(sql="SELECT " + select_query + " FROM " + table_name, con=self.mysql_connector)
# ...

# %%
for i in result_dict['all']:
    print(len(result_dict[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 for i in result_dict['all']:
# ----> 2     print(len(result_dict[i]))
#
# TypeError: unhashable type: 'DataFrame'

# %% [markdown]
# ##### load and predict for every category

# %%
from cnt.evaluate import Metrics
metrics = Metrics()

# %%
y_pred_all, y_test_all, metric_scores_all = result_dict['all']
[y  for x in y_test_all.y_test['y'] for y in x]
# Out:
# [('Zeus', 'PERSON', 'resting_on', 'serpent staff', 'OBJECT'),
#  ('Hermes', 'PERSON', 'holding', 'petasus', 'OBJECT'),
#  ('Hermes', 'PERSON', 'holding', 'chlamys', 'OBJECT'),
#  ('Hermes', 'PERSON', 'holding', 'staff', 'OBJECT'),
#  ('Hermes', 'PERSON', 'holding', 'cantharus', 'OBJECT'),
#  ('Caracalla', 'PERSON', 'wearing', 'cuirass', 'OBJECT'),
#  ('Caracalla', 'PERSON', 'wearing', 'paludamentum', 'OBJECT'),
#  ('Caracalla', 'PERSON', 'holding', 'spear', 'OBJECT'),
#  ('Caracalla', 'PERSON', 'holding', 'shield', 'OBJECT'),
#  ('Demeter', 'PERSON', 'wearing', 'chiton', 'OBJECT'),
#  ('Demeter', 'PERSON', 'holding', 'corn', 'PLANT'),
#  ('Demeter', 'PERSON', 'holding', 'torch', 'OBJECT'),
#  ('Tyche', 'PERSON', 'seated_on', 'rock', 'OBJECT'),
#  ('Tyche', 'PERSON', 'resting_on', 'rock', 'OBJECT'),
#  ('Tyche', 'PERSON', 'holding', 'corn', 'PLANT'),
#  ('Demeter', 'PERSON', 'holding', 'patera', 'OBJECT'),
#  ('Demeter', 'PERSON', 'resting_on', 'torch', 'OBJECT'),
# ...

# %%
df = pd.DataFrame()
for cat in dict_categorys:
    if cat in result_dict:
        y_pred, traindata, metric_scores = result_dict[cat]
        y_test_count = 0
        if hasattr(traindata, "y_test"):
            y_test = traindata.y_test['y']
            x_test = traindata.x_test['y']
            y_test_count = len([y  for x in y_test for y in x])
            x_test_count = len([y  for x in x_test for y in x])
        all_scores = {'category': cat, }#"relationen": y_test_count }
        for metric_value in metric_scores:
            all_scores[metric_value] = metric_scores[metric_value]
        score_row = pd.DataFrame([all_scores])
        df = pd.concat([df, score_row], ignore_index=True)

# %%
df
# Out:
#          category  Hamming Loss  Subset Accuracy  Jaccard Index  \
# 0             all          2.52             0.12          28.41
# 1         from CN          2.78             0.86          28.84
# 2       from OCRE          0.00             0.00           0.00
# 3    from RE_yaml          7.08             9.59          36.21
# 4  auto_generated         13.88             1.64          26.78
#
#    Precision (scikit-learn)  Recall (scikit-learn)  F1 Score (scikit-learn)  \
# 0                     42.90                  42.94                    42.89
# 1                     43.13                  43.08                    43.08
# 2                      0.00                   0.00                     0.00
# 3                     49.04                  49.04                    49.04
# 4                     40.33                  40.33                    40.33
#
#    Precision  Recall     F1
# 0      96.47   49.52  65.44
# 1      95.87   47.79  63.78
# 2       0.00    0.00   0.00
# ...

# %%
df.transpose()
# Out:
#                               0        1          2             3  \
# category                    all  from CN  from OCRE  from RE_yaml
# Hamming Loss               2.52     2.78        0.0          7.08
# Subset Accuracy            0.12     0.86        0.0          9.59
# Jaccard Index             28.41    28.84        0.0         36.21
# Precision (scikit-learn)   42.9    43.13        0.0         49.04
# Recall (scikit-learn)     42.94    43.08        0.0         49.04
# F1 Score (scikit-learn)   42.89    43.08        0.0         49.04
# Precision                 96.47    95.87        0.0         98.57
# Recall                    49.52    47.79        0.0         46.62
# F1                        65.44    63.78        0.0          63.3
#
#                                        4
# category                  auto_generated
# Hamming Loss                       13.88
# Subset Accuracy                     1.64
# Jaccard Index                      26.78
# ...
